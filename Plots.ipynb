# %%
import pandas as pd
from datetime import datetime, date, timedelta
import numpy as np
import altair as alt
import importlib
from IPython.display import display
pd.options.display.max_columns = None

# %%
import charts_empirical

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/CA_Bay_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/CA_Los Angeles_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/NY_New York City_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/UT_Salt Lake_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
importlib.reload(charts_empirical)
c = charts_empirical.plot_dynamic_doubling_fit(d)
c
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# alt.LayerChart(...)

# %%
importlib.reload(charts_empirical)
charts_empirical.plot_Rt_fit(d)
# Out:
# alt.LayerChart(...)

# %%
importlib.reload(charts_empirical)
c = charts_empirical.plot_daily_cases(d)
c
# Out:
# alt.LayerChart(...)

# %%
d
# Out:
#                   rgn      pop       date  cases  cumCases  fixed  deaths  \
# 0    NY:New York City  8398748 2020-03-01    1.0       1.0      0     0.0
# 1    NY:New York City  8398748 2020-03-02    0.0       1.0      0     0.0
# 2    NY:New York City  8398748 2020-03-03    1.0       2.0      0     0.0
# 3    NY:New York City  8398748 2020-03-04    0.0       2.0      0     0.0
# 4    NY:New York City  8398748 2020-03-05    2.0       4.0      0     0.0
# ..                ...      ...        ...    ...       ...    ...     ...
# 301  NY:New York City  8398748 2020-12-27    NaN       NaN      0     NaN
# 302  NY:New York City  8398748 2020-12-28    NaN       NaN      0     NaN
# 303  NY:New York City  8398748 2020-12-29    NaN       NaN      0     NaN
# 304  NY:New York City  8398748 2020-12-30    NaN       NaN      0     NaN
# 305  NY:New York City  8398748 2020-12-31    NaN       NaN      0     NaN
#
#             Rt     RtLCL      RtUCL   seg           b0       gRt       dbT  \
# ...

# %%
# Scratch

# %%
a = pd.DataFrame({"col":[datetime(2020, 6, 12, 5, 23, 23), datetime(2020, 7, 12, 5, 23, 23)], "b":[239, 23]})
a.dtypes
# Out:
# col    datetime64[ns]
# b               int64
# dtype: object

# %%
a.col = a.col.apply(lambda d: (d + timedelta(hours=6)).date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-984e41eaca9a> in <module>
# ----> 1 a.col = a.col.apply(lambda d: (d + timedelta(hours=6)).date)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-196-984e41eaca9a> in <lambda>(d)
# ----> 1 a.col = a.col.apply(lambda d: (d + timedelta(hours=6)).date)
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'datetime.timedelta'

# %%
a
# Out:
#                                                  col    b
# 0  <built-in method date of Timestamp object at 0...  239
# 1  <built-in method date of Timestamp object at 0...   23
