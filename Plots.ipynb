# %%
import pandas as pd
from datetime import datetime, date, timedelta
import numpy as np
import altair as alt
import importlib
from IPython.display import display
pd.options.display.max_columns = None

# %%
import sys
sys.path.append("src/penn_chime")
import empirical_charts
import body_text
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-8ff0862069bf> in <module>
#       2 sys.path.append("src/penn_chime")
#       3 import empirical_charts
# ----> 4 import body_text
#
# ~/Documents/Repos/chime/src/penn_chime/body_text.py in <module>
#       1 import streamlit as st
#       2
# ----> 3 from .parameters import Parameters, Mode
#       4 from .model_base import SimSirModelBase as Model
#       5 from .hc_actuals import actuals_download_widget
#
# ImportError: attempted relative import with no known parent package

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/CA_Bay_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/CA_Los Angeles_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/NY_New York City_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
d = pd.read_table('~/Health Catalyst, Inc/Data Science - Documents/Products/COVID19/DynamicDoubling/SampleData/UT_Salt Lake_Out.txt').assign(date = lambda d: pd.to_datetime(d.date))

# %%
importlib.reload(empirical_charts)
c = empirical_charts.plot_dynamic_doubling_fit(d)
c
# Out:
# alt.LayerChart(...)

# %%
importlib.reload(empirical_charts)
empirical_charts.plot_Rt_fit(d)
# Out:
# alt.LayerChart(...)

# %%
importlib.reload(empirical_charts)
c = empirical_charts.plot_daily_cases(d)
c
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Scratchhhh

# %%
a = "hi"
isinstance(a, str)
# Out:
# True

# %%
import datetime
d = pd.DataFrame({"date":[datetime.datetime(2020, 6, 12, 6, 0, 0), datetime.datetime(2022, 6, 12, 6, 0, 0)], 
                  "b":[1, 2]})
d
# Out:
#                  date  b
# 0 2020-06-12 06:00:00  1
# 1 2022-06-12 06:00:00  2

# %%
d.date.loc[d.b==1].max().strftime("%b %d")
# Out:
# 'Jun 12'

# %%
"a  ".strip()
# Out:
# 'a'
